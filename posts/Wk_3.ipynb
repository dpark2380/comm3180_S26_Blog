# %% [raw]
# ---
# title: "Class Wk 3"
# description: "Example post"
# author: "Daniel Park"
# date: "1/28/2026"
# ---

# %% [markdown]
# ---
# Section 1
# ---
# ### Markdown content

# %%
print("This is some code")
# Out:
# This is some code
