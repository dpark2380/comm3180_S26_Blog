# %% [raw]
# ---
# title: "Daniel's Blog 1"
# description: "Testing Blogging"
# author: "Daniel"
# date: "1/23/2025"
# categories:
#   - LLMs
#   - Machine Learning
# ---

# %% [markdown]
# Markdown content.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
